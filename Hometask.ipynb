# %% [markdown]
# <a href="https://colab.research.google.com/github/Lama1421f/python-lab/blob/main/Hometask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Home Task**

# %%
import requests
page = requests.get("https://programminghistorian.org/en/lessons/normalizing-data")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en">\n\n  <head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\n  \n  \r\n\r\n<meta name="citation_title" content="Normalizing Textual Data with Python" />\r\n\r\n<meta name="citation_author" content="William J. Turkel" />\r\n\r\n<meta name="citation_author" content="Adam Crymble" />\r\n\r\n<meta name="citation_publication_date" content="2012-07-17" />\r\n<meta name="citation_journal_title" content="Programming Historian" />\r\n<meta name="citation_public_url" content="https://programminghistorian.org/en/lessons/normalizing-data" />\r\n\n  \n\n  \n  <!--https://dev.twitter.com/cards/-->\n\n\n\n\n\n\n\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:site" content="@ProgHist" />\n<meta name="twitter:title" content="Normalizing Textual Data with Python" />\n\n\n    <meta name="twitter:description" content="In this lesson, we will make the list we created in the \'From HTML to a List of
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="Normalizing Textual Data with Python" name="citation_title">
#    <meta content="William J. Turkel" name="citation_author">
#     <meta content="Adam Crymble" name="citation_author"/>
#     <meta content="2012-07-17" name="citation_publication_date"/>
#     <meta content="Programming Historian" name="citation_journal_title"/>
#     <meta content="https://programminghistorian.org/en/lessons/normalizing-data" name="citation_public_url"/>
#     <!--https://dev.twitter.com/cards/-->
#     <meta content="summary" name="twitter:card"/>
#     <meta content="@ProgHist" name="twitter:site"/>
#     <meta content="Normalizing Textual Data with Python" name="twitter:title"/>
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p>In this lesson, we will make the list we created in the ‘From HTML to a List of Words’ lesson easier to analyze by normalizing this data.</p>,
#  <p>
#  <i class="fas fa-user-check"></i> Peer-reviewed
#
#                  </p>,
#  <p><a href="https://creativecommons.org/licenses/by/4.0/deed.en"><i class="fas fa-lock-open"></i> CC-BY
#                      4.0</a></p>,
#  <p><a href="/en/individual"><i class="fas fa-credit-card"></i> Support PH</a></p>,
#  <p> <img alt="DOI id icon" src="/images/doi_icon.jpg" style="max-width:16px;display:inline;" width="16px"/> https://doi.org/10.46430/phen0014</p>,
#  <p>Great Open Access tutorials cost money to produce. Join the growing number of people <a href="https://www.patreon.com/theprogramminghistorian">supporting <em>Programming Historian</em></a> so we can continue to share knowledge free of charge.</p>,
#  <p>The list that we created in the <a href="/lessons/from-html-to-list-of-words-2">From HTML to a List of Words (2)</a>
# ...

# %%
soup.find_all('p', class_='suggested-citation-text')
# Out:
# [<p class="suggested-citation-text">
#
#
#
#  William J. Turkel and Adam Crymble,
#          "Normalizing Textual Data with Python,"
#          <em>Programming Historian</em> 1 (2012),
#          https://doi.org/10.46430/phen0014.</p>]

# %%
soup.find_all('h2',id="donate-today")
# Out:
# [<h2 id="donate-today">Donate today!</h2>,
#  <h2 id="donate-today">Donate today!</h2>]

# %%
soup.find_all('div', class_="alert alert-warning")
# Out:
# [<div class="alert alert-warning">
#  <!-- Banner pointing to the original and other translations of this lesson when they exist -->
#      Available in:
#
#      <a href="/en/lessons/normalizing-data"> EN
#      </a> (original) |
#
#
#
#      <a href="/es/lecciones/normalizar-datos"> ES </a>
#  </div>]
