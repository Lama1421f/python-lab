# %% [markdown]
# <a href="https://colab.research.google.com/github/Lama1421f/python-lab/blob/main/hometask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Home Task**

# %%
import requests
page = requests.get("https://en-sa.namshi.com/?utm_source=google&utm_medium=cpc&utm_content=namshi%20ksa&utm_campaign=sa_search_cb-010001_namshi-ext_en_desktop-tab&gclid=CjwKCAjwwL6aBhBlEiwADycBINJbxa3pLvryRvWCeLeY29Kaa0_Wd-iCgQ-xdfxsHIvgtuFlt0nhohoCEy4QAvD_BwE")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<html lang="en" class="en  ab_lowInStockUrgencyDriver">\n<head>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta charset="utf-8">\n<meta name="viewport" content="width=1200" />\n<meta name=\'Petal-Search-site-verification\' content=\'b6e6be2f76\' />\n<link preconnect="https://a.namshicdn.com" crossorigin />\n<link rel="preload" href="https://a.namshicdn.com/web-desktop/main-7474435b6a9bb2ba00b4.css" as="style" />\n<link rel="preload" href="https://a.namshicdn.com/web-desktop/vendor-f6dd4e2091a8755984ef.js" as="script" />\n<link rel="preload" href="https://a.namshicdn.com/web-desktop/app-5f65ef101ee441ddfb5a.js" as="script" />\n<link rel="apple-touch-icon" href="//a.namshicdn.com/cms/misc/icons/apple-touch-icon.png">\n<link rel="apple-touch-icon" sizes="60x60" href="//a.namshicdn.com/cms/misc/icons/apple-touch-icon-60x60.png">\n<link rel="apple-touch-icon" sizes="114x114" href="//a.namshicdn.com/cms/misc/icons/apple-touch-icon-114x114.png">\n<link rel="apple-
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <html class="en ab_lowInStockUrgencyDriver" lang="en">
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=1200" name="viewport">
#    <meta content="b6e6be2f76" name="Petal-Search-site-verification"/>
#    <link crossorigin="" preconnect="https://a.namshicdn.com"/>
#    <link as="style" href="https://a.namshicdn.com/web-desktop/main-7474435b6a9bb2ba00b4.css" rel="preload"/>
#    <link as="script" href="https://a.namshicdn.com/web-desktop/vendor-f6dd4e2091a8755984ef.js" rel="preload"/>
#    <link as="script" href="https://a.namshicdn.com/web-desktop/app-5f65ef101ee441ddfb5a.js" rel="preload"/>
#    <link href="//a.namshicdn.com/cms/misc/icons/apple-touch-icon.png" rel="apple-touch-icon"/>
#    <link href="//a.namshicdn.com/cms/misc/icons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p style="margin-bottom:20px;font-size:18px;font-weight:300;color:#222;"><span style="font-weight: 400;">Offering the latest trends for </span><a href="/men/"><span style="font-weight: 400;">men</span></a><span style="font-weight: 400;">, </span><a href="/women/"><span style="font-weight: 400;">women</span></a><span style="font-weight: 400;"> and </span><a href="/kids/"><span style="font-weight: 400;">kids</span></a><span style="font-weight: 400;">, Namshi is your top choice for </span><span style="font-weight: 400;">online shopping in Saudi Arabia</span><span style="font-weight: 400;">. We've got a growing range of brands ranging from </span><a href="/nike/"><span style="font-weight: 400;">Nike</span></a><span style="font-weight: 400;"> to </span><a href="/ginger/"><span style="font-weight: 400;">Ginger</span></a><span style="font-weight: 400;">, </span><a href="/puma/"><span style="font-weight: 400;">Puma</span></a><span style="font-weight: 400;">, </span><a href="/adidas/"><span 
# ...

# %%
soup.find_all('p', class_='title')
# Out:
# [<p class="title">Other Countries</p>,
#  <p class="title">About Us</p>,
#  <p class="title">Customer Services</p>,
#  <p class="title">Our Top Categories</p>,
#  <p class="title">Our Top Brands</p>]
